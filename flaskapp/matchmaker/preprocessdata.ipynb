# %%
import names
import pandas as pd
import random
from random import randint

# %%
mentors = pd.read_csv('mentors.csv')

# %%
mentors['job_desc']=mentors['job_desc'].str.replace("'", "")

# %%
mentors
# Out:
#      id name  school   job_title  \
# 0     1  서강준   서울대학교    스타트업 CEO
# 1     2  김서준  가톨릭대학교       UX/UI
# 2     3  이하준   고려대학교   우주공학 엔지니어
# 3     4  박도윤   건국대학교  반도체개발 엔지니어
# 4     5  김시우   경기대학교        경영평가
# ..  ...  ...     ...         ...
# 95   96  안나은  가톨릭대학교       UX/UI
# 96   97  송아린   고려대학교  건축구조설계엔지니어
# 97   98  권다은   건국대학교     방송콘텐츠제작
# 98   99  허유주   충남대학교        고객관리
# 99  100  유채원   연세대학교        경영평가
#
#                                          job_desc                 image_file  \
# 0    삼산텍에서 CEO로서 직원채용, 투자유치 그리고 IR 등을 담당하고 있습니다.'    profile_pic_mentor1.jpg
# 1              인공위성 발사체 1단 로켓엔진을 설계하는 일을 맡고 있습니다'    profile_pic_mentor2.jpg
# 2                                             NaN    profile_pic_mentor3.jpg
# 3   삼성에서 반도체를 만들때 발생되는 화학폐기물을 처리하는 기술을 개발하고 있습니다'    profile_pic_mentor4.jpg
# 4         물류회사에서 분기별 실적을 검사하고 문제점을 찾는 일을 하고 있습니다'    profile_pic_mentor5.jpg
# ..                                            ...                        ...
# ...

# %%
for index,row in mentors.iterrows():
    
    username = 'test'+str(row['id'])
    password = '1234'
    email = username + '@mm.com'
    
    mentors.loc[index, 'username'] = username
    mentors.loc[index, 'password'] = password
    mentors.loc[index, 'email'] = email

# %%
mentors.to_csv('mentors_updated.csv')
